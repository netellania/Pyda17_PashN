# %%
import pandas as pd

# %%
#Задание 1
#Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#KEYWORDS = ['python', 'парсинг']
#Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>

import requests

# %%
res = requests.get('https://habr.com/ru/all/')
res
# Out:
# <Response [200]>

# %%
KEYWORDS = ['python', 'парсинг']

# %%
from bs4 import BeautifulSoup

# %%
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# %%
posts = soup.find_all('article', class_='post')
posts
# Out:
# [<article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/triumphpc/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/317/03d/328/31703d3286f010e6fca6f4710e24144d.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">triumphpc</span>
#  </a>
#  <span class="post__time">сегодня в 22:22</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/552278/">Strategy Design Pattern</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
# ...

# %%
postss = soup.find_all('span', class_='post__time')
title_element = post.find('span', class_='post__time')
#postss

print(title_element.text )
# Out:
# сегодня в 20:25

# %%
title_element = post.find('a', class_='post__title_link')
print(title_element.text)
# Out:
# Шифрование сообщений в Python. От простого к сложному. Шифр Цезаря

# %%
for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    hubs = post.find_all('a', class_='hub-link')
   # date = post.find_all('span', class_d='post__time')
    for hub in hubs:
            hub_lower = hub.text.lower()
           # ищем вхождение хотя бы одного желаемого хаба
            if any([hub_lower in desired for desired in KEYWORDS]):
                title_element2 = post.find('span', class_='post__time')
                title_element = post.find('a', class_='post__title_link')
                print(title_element2.text, title_element.text, title_element.attrs.get('href'))
               # так как пост уже нам подошел - дальше нет смысла проверять хабы
                break
# Out:
# сегодня в 20:25 Шифрование сообщений в Python. От простого к сложному. Шифр Цезаря https://habr.com/ru/post/552212/

# %%
# Задание 2
#Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck.
#Список email-ов задаем переменной в начале кода:
#EMAIL = [xxx@x.ru, yyy@y.com]
#В итоге должен формироваться датафрейм со столбцами: 
#<почта> - <дата утечки> - <источник утечки> - <описание утечки>
#Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.
res1 = requests.get('https://www.avast.com')
res1
# Out:
# <Response [200]>

# %%
EMAIL = ['xxx@x.ru', 'yyy@y.com']

# %%
from bs4 import BeautifulSoup

# %%
req1 = requests.get('https://www.avast.com')
soup1 = BeautifulSoup(req1.text, 'html.parser')
soup1
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ru">
# <head>
# <script src="https://cdn.cookielaw.org/consent/0d5e8323-a7c8-44d2-aee6-96462c6b582e/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-document-language="true" data-domain-script="0d5e8323-a7c8-44d2-aee6-96462c6b582e" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
# function OptanonWrapper() {
# 	var cookieBannerContainer = document.getElementById("onetrust-consent-sdk");
#   	document.body.prepend(cookieBannerContainer);
# }
# </script>
# <meta charset="utf-8"/>
# <script>
#     /*! Declare GTM dataLayer */
#     window.dataLayer = window.dataLayer || [];
#
#     /*! Dimensions to dataLayer */
#     (function(){
#         var dataObj = {
#             'contentLocale': 'ru-ru',
#             'pageName': 'ru-ru | index',
#             'pageId': 'e6d958350045710190f7db8120636d21'
#         };
# ...

# %%
req2 = requests.get('https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data')
req2
# Out:
# <Response [404]>

# %%
soup2 = BeautifulSoup(req2.text, 'html.parser')
soup2
# Out:
# Not found
